# %% [markdown]
# # Assignment 5. k-Nearest Neighbors.
# ## Introduction
# We're using the glass classification dataset (https://www.kaggle.com/uciml/glass) to predict the type of the glass based on its components.
# ## Step 1. Initializing imports.

# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()
from sklearn.datasets import make_blobs
from sklearn.neighbors import KNeighborsClassifier
from sklearn import metrics
from sklearn import datasets
from sklearn.model_selection import train_test_split
from sklearn.ensemble import BaggingClassifier
from sklearn.metrics import classification_report
from sklearn.utils.testing import ignore_warnings
from sklearn.exceptions import UndefinedMetricWarning
from sklearn.exceptions import ConvergenceWarning
from sklearn.linear_model import LogisticRegression
from sklearn.feature_selection import RFECV

# %% [markdown]
# ## Step 2. Loading and transforming the dataset.

# %%
df = pd.read_csv('glass.csv')
y = df['Type']
df = df.drop('Type', axis=1)
X = df

# %% [markdown]
# ## Step 3. Splitting the train and test dataset.

# %%
x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)

# %% [markdown]
# ## Step 4. Implementing the k-Nearest Neighbors algorightm.
# k is the parameter for how many neighbors we want to select.

# %%
@ignore_warnings(category=UndefinedMetricWarning)
def kneigh(k):
    neigh = KNeighborsClassifier(n_neighbors=k)
    neigh.fit(x_train, y_train)
    predictions = neigh.predict(x_test)
    score = neigh.score(x_test, y_test)
    print(classification_report(y_test, predictions))
    cm = metrics.confusion_matrix(y_test, predictions)
    plt.figure(figsize=(10,10))
    sns.heatmap(cm, annot=True, linewidths=.5, square = True, cmap = 'Reds', xticklabels=[1,2,3,5,6,7], yticklabels=[1,2,3,5,6,7]);
    plt.ylabel('Actual label');
    plt.xlabel('Predicted label');
    all_sample_title = 'Accuracy Score: {0}'.format(score)
    plt.title(all_sample_title, size = 15);

# %%
kneigh(2)
# Out:
#               precision    recall  f1-score   support
#
#            1       0.57      0.81      0.67        37
#            2       0.82      0.69      0.75        39
#            3       0.00      0.00      0.00        12
#            5       0.40      1.00      0.57         2
#            6       0.67      0.67      0.67         3
#            7       0.92      0.79      0.85        14
#
#     accuracy                           0.67       107
#    macro avg       0.56      0.66      0.58       107
# weighted avg       0.64      0.67      0.64       107

# %%
kneigh(3)
# Out:
#               precision    recall  f1-score   support
#
#            1       0.54      0.70      0.61        37
#            2       0.77      0.69      0.73        39
#            3       0.20      0.08      0.12        12
#            5       0.50      1.00      0.67         2
#            6       0.67      0.67      0.67         3
#            7       0.92      0.79      0.85        14
#
#     accuracy                           0.64       107
#    macro avg       0.60      0.66      0.61       107
# weighted avg       0.64      0.64      0.63       107

# %%
kneigh(4)
# Out:
#               precision    recall  f1-score   support
#
#            1       0.58      0.78      0.67        37
#            2       0.71      0.69      0.70        39
#            3       0.67      0.17      0.27        12
#            5       0.40      1.00      0.57         2
#            6       0.00      0.00      0.00         3
#            7       1.00      0.79      0.88        14
#
#     accuracy                           0.66       107
#    macro avg       0.56      0.57      0.51       107
# weighted avg       0.67      0.66      0.64       107

# %%
kneigh(5)
# Out:
#               precision    recall  f1-score   support
#
#            1       0.56      0.73      0.64        37
#            2       0.64      0.59      0.61        39
#            3       0.67      0.17      0.27        12
#            5       0.22      1.00      0.36         2
#            6       0.00      0.00      0.00         3
#            7       1.00      0.79      0.88        14
#
#     accuracy                           0.61       107
#    macro avg       0.52      0.55      0.46       107
# weighted avg       0.64      0.61      0.60       107

# %%
kneigh(6)
# Out:
#               precision    recall  f1-score   support
#
#            1       0.55      0.76      0.64        37
#            2       0.67      0.56      0.61        39
#            3       0.67      0.17      0.27        12
#            5       0.22      1.00      0.36         2
#            6       0.00      0.00      0.00         3
#            7       1.00      0.79      0.88        14
#
#     accuracy                           0.61       107
#    macro avg       0.52      0.55      0.46       107
# weighted avg       0.64      0.61      0.59       107

# %%
kneigh(7)
# Out:
#               precision    recall  f1-score   support
#
#            1       0.56      0.73      0.64        37
#            2       0.59      0.51      0.55        39
#            3       0.67      0.17      0.27        12
#            5       0.20      1.00      0.33         2
#            6       0.00      0.00      0.00         3
#            7       1.00      0.79      0.88        14
#
#     accuracy                           0.58       107
#    macro avg       0.50      0.53      0.44       107
# weighted avg       0.62      0.58      0.57       107

# %%
kneigh(8)
# Out:
#               precision    recall  f1-score   support
#
#            1       0.56      0.81      0.66        37
#            2       0.67      0.51      0.58        39
#            3       0.00      0.00      0.00        12
#            5       0.20      1.00      0.33         2
#            6       0.00      0.00      0.00         3
#            7       0.92      0.79      0.85        14
#
#     accuracy                           0.59       107
#    macro avg       0.39      0.52      0.40       107
# weighted avg       0.56      0.59      0.56       107

# %%
kneigh(9)
# Out:
#               precision    recall  f1-score   support
#
#            1       0.53      0.73      0.61        37
#            2       0.61      0.51      0.56        39
#            3       0.00      0.00      0.00        12
#            5       0.20      1.00      0.33         2
#            6       0.00      0.00      0.00         3
#            7       0.92      0.79      0.85        14
#
#     accuracy                           0.56       107
#    macro avg       0.38      0.50      0.39       107
# weighted avg       0.53      0.56      0.53       107

# %%
kneigh(10)
# Out:
#               precision    recall  f1-score   support
#
#            1       0.54      0.78      0.64        37
#            2       0.61      0.49      0.54        39
#            3       0.00      0.00      0.00        12
#            5       0.20      1.00      0.33         2
#            6       0.00      0.00      0.00         3
#            7       1.00      0.79      0.88        14
#
#     accuracy                           0.57       107
#    macro avg       0.39      0.51      0.40       107
# weighted avg       0.54      0.57      0.54       107

# %% [markdown]
# The results will continue decreasing with the increase of the parameter k, so we will stop now.

# %%
@ignore_warnings(category=UndefinedMetricWarning)
def logisticClassifier():
    logisticRegr = RFECV(LogisticRegression(max_iter=5000), scoring='accuracy')
    logisticRegr.fit(x_train, y_train)
    score = logisticRegr.score(x_test, y_test)
    predictions = logisticRegr.predict(x_test)
    print(classification_report(y_test, predictions))
    cm = metrics.confusion_matrix(y_test, predictions)
    plt.figure(figsize=(10,10))
    sns.heatmap(cm, annot=True, linewidths=.5, fmt='d', square = True, cmap = 'Reds',xticklabels=[1,2,3,5,6,7], yticklabels=[1,2,3,5,6,7]);
    plt.ylabel('Actual label');
    plt.xlabel('Predicted label');
    all_sample_title = 'Accuracy Score: {0}'.format(score)
    plt.title(all_sample_title, size = 15);

# %%
logisticClassifier()
# Out:
#               precision    recall  f1-score   support
#
#            1       0.58      0.57      0.58        37
#            2       0.49      0.59      0.53        39
#            3       0.00      0.00      0.00        12
#            5       0.29      1.00      0.44         2
#            6       0.33      0.33      0.33         3
#            7       0.93      0.93      0.93        14
#
#     accuracy                           0.56       107
#    macro avg       0.44      0.57      0.47       107
# weighted avg       0.52      0.56      0.53       107

# %% [markdown]
# ## Step 5. Conclusion
# The k-Nearest Neighbors has performed better than the Logistic Regression. The k-Nearest Neighbors with k=2 has performed the best with the accuracy above 0.67, which is decent.
